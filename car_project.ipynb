# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenziart/sokrab/blob/main/car_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("electronics.csv")

# %%
df.head()
# Out:
#     AKM1MP6P0OYPR  0132793040  5.0  1365811200
# 0  A2CX7LUOHB2NDG  0321732944  5.0  1341100800
# 1  A2NWSAGRHCP8N5  0439886341  1.0  1367193600
# 2  A2WNBOD3WNDNKT  0439886341  3.0  1374451200
# 3  A1GI0U4ZRJA8WN  0439886341  1.0  1334707200
# 4  A1QGNMC6O1VW39  0511189877  5.0  1397433600

# %%
df.tail()
# Out:
#           AKM1MP6P0OYPR  0132793040  5.0    1365811200
# 1313177  A1CHF97PFL1A9Z  B000QUUFRW  1.0  1.336694e+09
# 1313178  A1X0Q1XR6MZZ02  B000QUUFRW  5.0  1.370477e+09
# 1313179   A46PQC3OBQSBD  B000QUUFRW  5.0  1.389658e+09
# 1313180  A2KO6F74DELLQ4  B000QUUFRW  4.0  1.344211e+09
# 1313181            A8WS         NaN  NaN           NaN

# %%
df.rename(columns={"AKM1MP6P0OYPR":"name",'0132793040':'id_number','1365811200':'numbers'},inplace=True)

# %%
df.head()
# Out:
#              name   id_number  5.0       numbers
# 0  A2CX7LUOHB2NDG  0321732944  5.0  1.341101e+09
# 1  A2NWSAGRHCP8N5  0439886341  1.0  1.367194e+09
# 2  A2WNBOD3WNDNKT  0439886341  3.0  1.374451e+09
# 3  A1GI0U4ZRJA8WN  0439886341  1.0  1.334707e+09
# 4  A1QGNMC6O1VW39  0511189877  5.0  1.397434e+09

# %%
duplicate=df[df.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [name, id_number, 5.0, numbers]
# Index: []

# %%
df.nunique()
# Out:
# name         956063
# id_number     76555
# 5.0               5
# numbers        5489
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name         0
# id_number    1
# 5.0          1
# numbers      1
# dtype: int64

# %%
top_electronics=df['5.0'].value_counts().head(10)
print(top_electronics)

#visualization

plt.figure(figsize=(12,6))
sns.barplot(x=top_electronics.index,y=top_electronics.values,orient='y')
# Out:
# 5.0
# 5.0    710950
# 4.0    260820
# 1.0    159610
# 3.0    104066
# 2.0     77735
# Name: count, dtype: int64
# <Axes: xlabel='5.0'>

# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenziart/sokrab/blob/main/product__recomandation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("rating.csv")

# %%
df.head()
# Out:
#          L493NOJ6P  B0016G8I2Y  5.0    1223683200
# 0    ACXK4B4SBZBKN  B0016G8I2Y  3.0  1.298678e+09
# 1   A2IHCKXS70FU4I  B0016G8I2Y  5.0  1.358294e+09
# 2    AT35X4WQXK84G  B0016G8I2Y  1.0  1.237594e+09
# 3    A871PQ04YLDY8  B0016G8I2Y  4.0  1.257552e+09
# 4   A14M81B70VXCHU  B0016G8I2Y  1.0  1.227312e+09
# 5   A19D09NGFBW0ZT  B0016G8I2Y  5.0  1.258675e+09
# 6   A29DVZFUG5XWN9  B0016G8I2Y  4.0  1.283645e+09
# 7   A3DRLIBJEJ6GJA  B0016G8I2Y  5.0  1.312934e+09
# 8   A22VBSTRFK8PYU  B0016G8I2Y  4.0  1.262995e+09
# 9   A1C8Y009ZI3BCD  B0016G8I2Y  1.0  1.211674e+09
# 10  A168VVXTD7PX1B  B0016G8I2Y  1.0  1.280448e+09
# 11   A1U78VI1WFS1E  B0016G8I38  1.0  1.300838e+09
# 12  A3KKVDVS9UV2LL  B0016G8I38  5.0  1.386029e+09
# 13  A1CZK5X93UMTE7  B0016G8I38  5.0  1.300234e+09
# 23   A27IMUKHRWLD8  B0016G8I38  4.0  1.275523e+09
# 25  A2SQOZEPXXTJ6Y  B0016G8I38  3.0  1.362528e+09
# 26   ABOCQYVRCE4JB  B0016G8I38  3.0  1.329005e+09
# 27  A1N1UQZS4G6GV9  B0016G8I38  4.0  1.293840e+09
# 28  A2K5YPT3Z63YWY  B0016G8I38  2.0  1.268525e+09
# 35  A2VJKE983DYPTX  B0016G9NXM  2.0  1.251677e+09
# 43  A1W60Z7OGXOVEP  B0016G9NXM  2.0  1.244419e+09
# 45  A38BYW7OKWEX89  B0016G9NXM  3.0  1.246925e+09
# 46  A20ZWLKOWC37YG  B0016G9NXM  3.0  1.392163e+09
# 49  A1LRNF2ZBUCUPR  B0016G9NXM  2.0  1.259280e+09
# 64  A17O9AHKHK66AI  B0016G9NXM  2.0  1.259626e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797898 entries, 0 to 797897
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   L493NOJ6P   797898 non-null  object
#  1   B0016G8I2Y  797897 non-null  object
#  2   5.0         797897 non-null  float64
#  3   1223683200  797897 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 24.4+ MB

# %%
df.dtypes
# Out:
# L493NOJ6P      object
# B0016G8I2Y     object
# 5.0           float64
# 1223683200    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# L493NOJ6P     0
# B0016G8I2Y    1
# 5.0           1
# 1223683200    1
# dtype: int64

# %%
duplicate=df[df.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [L493NOJ6P, B0016G8I2Y, 5.0, 1223683200]
# Index: []

# %%
df.groupby(by='5.0').count()
# Out:
#      L493NOJ6P  B0016G8I2Y  1223683200
# 5.0
# 1.0      98092       98092       98092
# 2.0      47486       47486       47486
# 3.0      64831       64831       64831
# 4.0     151008      151008      151008
# 5.0     436480      436480      436480

# %%
df.nunique()
# Out:
# L493NOJ6P     654481
# B0016G8I2Y     42437
# 5.0                5
# 1223683200      2745
# dtype: int64

# %%
df.shape
# Out:
# (797898, 4)

# %%
plt.figure(figsize=(3,3))
sns.boxplot(x="5.0",data=df)
# Out:
# <Axes: xlabel='5.0'>

# %%
df.dropna()
# Out:
#              L493NOJ6P  B0016G8I2Y  5.0    1223683200
# 0        ACXK4B4SBZBKN  B0016G8I2Y  3.0  1.298678e+09
# 1       A2IHCKXS70FU4I  B0016G8I2Y  5.0  1.358294e+09
# 2        AT35X4WQXK84G  B0016G8I2Y  1.0  1.237594e+09
# 3        A871PQ04YLDY8  B0016G8I2Y  4.0  1.257552e+09
# 4       A14M81B70VXCHU  B0016G8I2Y  1.0  1.227312e+09
# ...                ...         ...  ...           ...
# 797892   A6KC46PMY1EM0  B002DHYKVS  4.0  1.383437e+09
# 797893  A1A1C01L1SVDDZ  B002DHYKVS  5.0  1.360022e+09
# 797894  A1L1U4IJK8ZXCF  B002DHYKVS  1.0  1.357603e+09
# 797895  A3I9IGMS9GHW8J  B002DHYKVS  4.0  1.369354e+09
# 797896   A89JL2WZMQK41  B002DHYKVS  5.0  1.374278e+09
#
# [797897 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# L493NOJ6P     0
# B0016G8I2Y    0
# 5.0           0
# 1223683200    0
# dtype: int64

# %%
df=df.dropna()
print(df)
# Out:
#              L493NOJ6P  B0016G8I2Y  5.0    1223683200
# 0        ACXK4B4SBZBKN  B0016G8I2Y  3.0  1.298678e+09
# 1       A2IHCKXS70FU4I  B0016G8I2Y  5.0  1.358294e+09
# 2        AT35X4WQXK84G  B0016G8I2Y  1.0  1.237594e+09
# 3        A871PQ04YLDY8  B0016G8I2Y  4.0  1.257552e+09
# 4       A14M81B70VXCHU  B0016G8I2Y  1.0  1.227312e+09
# ...                ...         ...  ...           ...
# 797892   A6KC46PMY1EM0  B002DHYKVS  4.0  1.383437e+09
# 797893  A1A1C01L1SVDDZ  B002DHYKVS  5.0  1.360022e+09
# 797894  A1L1U4IJK8ZXCF  B002DHYKVS  1.0  1.357603e+09
# 797895  A3I9IGMS9GHW8J  B002DHYKVS  4.0  1.369354e+09
# 797896   A89JL2WZMQK41  B002DHYKVS  5.0  1.374278e+09
#
# [797897 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# L493NOJ6P     0
# B0016G8I2Y    0
# 5.0           0
# 1223683200    0
# dtype: int64

# %%
df=df.describe()
print(df)
# Out:
#                  5.0    1223683200
# count       8.000000  8.000000e+00
# mean    99740.172791  9.767430e+08
# std    282097.958205  5.948318e+08
# min         1.000000  7.978970e+05
# 25%         2.601097  8.168189e+08
# 50%         4.488972  1.296443e+09
# 75%         5.000000  1.334016e+09
# max    797897.000000  1.406074e+09

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data=df)
# Out:
# <Axes: >

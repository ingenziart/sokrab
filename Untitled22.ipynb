# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenziart/sokrab/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libray
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cancer.csv")

# %%
df.head()
# Out:
#    Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 0       1         Heavy       Frequent          Low           Low
# 1       2    Occasional       Moderate         High          High
# 2       3           NaN            NaN         High          High
# 3       4         Heavy       Frequent          Low           Low
# 4       5      Moderate     Occasional       Medium        Medium
#
#   Jogging Habit  Probability of Cancer
# 0           Low                    0.8
# 1          High                    0.2
# 2          High                    0.1
# 3           Low                    0.9
# 4        Medium                    0.4

# %%
df.tail()
# Out:
#     Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 45      46         Heavy       Frequent          Low           Low
# 46      47      Moderate     Occasional       Medium        Medium
# 47      48           NaN            NaN         High          High
# 48      49         Heavy       Frequent          Low           Low
# 49      50      Moderate     Occasional       Medium        Medium
#
#    Jogging Habit  Probability of Cancer
# 45           Low                   0.80
# 46        Medium                   0.40
# 47          High                   0.01
# 48           Low                   0.75
# 49        Medium                   0.35

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr No.                 50 non-null     int64
#  1   Smoking Habit          34 non-null     object
#  2   Drinking Habit         34 non-null     object
#  3   Biking Habit           50 non-null     object
#  4   Walking Habit          50 non-null     object
#  5   Jogging Habit          50 non-null     object
#  6   Probability of Cancer  50 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
missing_value=df.isnull().sum()
print(missing_value)
# Out:
# Sr No.                    0
# Smoking Habit            16
# Drinking Habit           16
# Biking Habit              0
# Walking Habit             0
# Jogging Habit             0
# Probability of Cancer     0
# dtype: int64

# %%
from os.path import dirname
#df['Smoking Habit'].fillna(df['Smoking Habit'].mode()[0],inplace=True) #mode
df['Smoking Habit'].fillna("unknown",inplace=True)
df['Drinking Habit'].fillna("unkwon",inplace=True)
# Out:
# /tmp/ipython-input-784264680.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Smoking Habit'].fillna("unknown",inplace=True)
# /tmp/ipython-input-784264680.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
missing_value=df.isnull().sum()
print(missing_value)
# Out:
# Sr No.                   0
# Smoking Habit            0
# Drinking Habit           0
# Biking Habit             0
# Walking Habit            0
# Jogging Habit            0
# Probability of Cancer    0
# dtype: int64

# %%
df.nunique()
# Out:
# Sr No.                   50
# Smoking Habit             4
# Drinking Habit            4
# Biking Habit              3
# Walking Habit             3
# Jogging Habit             3
# Probability of Cancer    15
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="Smoking Habit",data=df)
# Out:
# <Axes: xlabel='Smoking Habit', ylabel='count'>

# %%
number_of_datasets=df.shape[0]
number_of_features=df.shape[1]-1
print(number_of_datasets,number_of_features)
# Out:
# 50 6

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()
oh=OneHotEncoder()

ordinal = ['Biking Habit', 'Walking Habit', 'Jogging Habit']   # os
nominal = ['Smoking Habit', 'Drinking Habit']

for col in ordinal:
  df[col]=le.fit_transform(df[col])
for col in ordinal:
    df[col] = le.fit_transform(df[col])
df = pd.get_dummies(df, columns=nominal , drop_first=True)

# %%
# Convert all boolean columns to int (0/1)
bool_cols = df.select_dtypes('bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df.head()
# Out:
#    Sr No.  Biking Habit  Walking Habit  Jogging Habit  Probability of Cancer  \
# 0       1             1              1              1                    0.8
# 1       2             0              0              0                    0.2
# 2       3             0              0              0                    0.1
# 3       4             1              1              1                    0.9
# 4       5             2              2              2                    0.4
#
#    Smoking Habit_Moderate  Smoking Habit_Occasional  Smoking Habit_unknown  \
# 0                       0                         0                      0
# 1                       0                         1                      0
# 2                       0                         0                      1
# 3                       0                         0                      0
# 4                       1                         0                      0
#
# ...

# %%
corr=df.drop(columns=['Sr No.']).corr()

plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True,)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,30))
sns.boxplot(data=df)

plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenziart/sokrab/blob/main/diabets_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
df=pd.read_csv('cancer.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr No.                 50 non-null     int64
#  1   Smoking Habit          34 non-null     object
#  2   Drinking Habit         34 non-null     object
#  3   Biking Habit           50 non-null     object
#  4   Walking Habit          50 non-null     object
#  5   Jogging Habit          50 non-null     object
#  6   Probability of Cancer  50 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
df.head()
# Out:
#    Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 0       1         Heavy       Frequent          Low           Low
# 1       2    Occasional       Moderate         High          High
# 2       3           NaN            NaN         High          High
# 3       4         Heavy       Frequent          Low           Low
# 4       5      Moderate     Occasional       Medium        Medium
#
#   Jogging Habit  Probability of Cancer
# 0           Low                    0.8
# 1          High                    0.2
# 2          High                    0.1
# 3           Low                    0.9
# 4        Medium                    0.4

# %%
#missing value

df.isnull().sum()

#there is missing value on smoking and drink habit .
# Out:
# Sr No.                    0
# Smoking Habit            16
# Drinking Habit           16
# Biking Habit              0
# Walking Habit             0
# Jogging Habit             0
# Probability of Cancer     0
# dtype: int64

# %%
duplicate=df.duplicated()
duplicate.sum()
#there is no duplicate
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Sr No.                     int64
# Smoking Habit             object
# Drinking Habit            object
# Biking Habit              object
# Walking Habit             object
# Jogging Habit             object
# Probability of Cancer    float64
# dtype: object

# %%
df.nunique()
# Out:
# Sr No.                   50
# Smoking Habit             3
# Drinking Habit            3
# Biking Habit              3
# Walking Habit             3
# Jogging Habit             3
# Probability of Cancer    15
# dtype: int64

# %%
df.describe()
# Out:
#          Sr No.  Probability of Cancer
# count  50.00000              50.000000
# mean   25.50000               0.407200
# std    14.57738               0.325501
# min     1.00000               0.010000
# 25%    13.25000               0.050000
# 50%    25.50000               0.375000
# 75%    37.75000               0.750000
# max    50.00000               0.900000

# %%
df.dropna()
# Out:
#     Sr No. Smoking Habit Drinking Habit Biking Habit Walking Habit  \
# 0        1         Heavy       Frequent          Low           Low
# 1        2    Occasional       Moderate         High          High
# 3        4         Heavy       Frequent          Low           Low
# 4        5      Moderate     Occasional       Medium        Medium
# 6        7         Heavy       Frequent          Low           Low
# 7        8      Moderate     Occasional       Medium        Medium
# 9       10         Heavy       Frequent          Low           Low
# 10      11      Moderate     Occasional       Medium        Medium
# 12      13         Heavy       Frequent          Low           Low
# 13      14      Moderate     Occasional       Medium        Medium
# 15      16         Heavy       Frequent          Low           Low
# 16      17      Moderate     Occasional       Medium        Medium
# 18      19         Heavy       Frequent          Low           Low
# ...

# %%
df.nunique()
# Out:
# Sr No.                   50
# Smoking Habit             3
# Drinking Habit            3
# Biking Habit              3
# Walking Habit             3
# Jogging Habit             3
# Probability of Cancer    15
# dtype: int64

# %%
df.dtypes
# Out:
# Sr No.                     int64
# Smoking Habit             object
# Drinking Habit            object
# Biking Habit              object
# Walking Habit             object
# Jogging Habit             object
# Probability of Cancer    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sr No.                    0
# Smoking Habit            16
# Drinking Habit           16
# Biking Habit              0
# Walking Habit             0
# Jogging Habit             0
# Probability of Cancer     0
# dtype: int64

# %%
df['Smoking Habit'].unique()
# Out:
# array([0, 2, 3, 1])

# %%
df = df.dropna(how='all')

# %%
df['Smoking Habit'].unique()
# Out:
# array([0, 2, 3, 1])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.columns:
    df[col] = le.fit_transform(df[col])

# %%
#heatmap

plt.figure(figsize=(10,8))
plt.style.use('classic')
plt.title("diabet heatmap ")
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: title={'center': 'diabet heatmap '}>

# %%
plt.figure(figsize=(10,8))
sns.countplot(df,x='Smoking Habit',color='red',palette='Set1')
# Out:
# <ipython-input-118-5c3717e7c2a8>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x='Smoking Habit',color='red',palette='Set1')
# <Axes: xlabel='Smoking Habit', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(df,palette='Set1')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Sr No.'),
#   Text(1, 0, 'Smoking Habit'),
#   Text(2, 0, 'Drinking Habit'),
#   Text(3, 0, 'Biking Habit'),
#   Text(4, 0, 'Walking Habit'),
#   Text(5, 0, 'Jogging Habit'),
#   Text(6, 0, 'Probability of Cancer')])
